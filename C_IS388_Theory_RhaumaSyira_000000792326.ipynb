# %% [markdown]
# ## <div align="center"> MIDTERM EXAM </div>
# ### <div align="center"> DATA ANALYSIS - LEC </div>
# #### <div align="center"> Semester Ganjil 2023/2024 </div>

# %%
import datetime
import uuid

studentName = "Rhauma Syira Anggina"
studentNIM = "00000079236"
studentClass = "IS388-C"

# %%
myDate = datetime.datetime.now()
myDevice = str(uuid.uuid1())

print("Name: \t\t{}".format(studentName))
print("NIM: \t\t{}".format(studentNIM))
print("NIM: \t\t{}".format(studentClass))
print("Start: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Rhauma Syira Anggina
# NIM: 		00000079236
# NIM: 		IS388-C
# Start: 		2023-10-20 19:06:45.513277
# Device ID: 	238e0a64-6f41-11ee-add8-9843fa3c851a

# %% [markdown]
# ### NUMBER 1

# %%
 # Import dataset format csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import scipy


# Import dataset dengan format csv
homicide = pd.read_csv("homicide.csv", encoding='latin1')
homicide
# Out:
#               uid  reported_date  victim_last victim_first victim_race  \
# 0      Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1      Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2      Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3      Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4      Alb-000005       20100102         MULA       VIVIAN       White
# ...           ...            ...          ...          ...         ...
# 52174  Was-001380       20160908     WILLIAMS         EVAN       Black
# 52175  Was-001381       20160913        SMITH         DEON       Black
# 52176  Was-001382       20161114   WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130       BARNES       MARCUS       Black
# 52178  Was-001384       20160901      JACKSON        KEVIN       Black
#
#       victim_age victim_sex         city state        lat         lon  \
# ...

# %%
print(homicide.shape)
# Out:
# (52179, 12)

# %%
homicide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52179 entries, 0 to 52178
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   uid            52179 non-null  object
#  1   reported_date  52179 non-null  int64
#  2   victim_last    52178 non-null  object
#  3   victim_first   52179 non-null  object
#  4   victim_race    52179 non-null  object
#  5   victim_age     52179 non-null  object
#  6   victim_sex     52179 non-null  object
#  7   city           52179 non-null  object
#  8   state          52179 non-null  object
#  9   lat            52119 non-null  float64
#  10  lon            52119 non-null  float64
#  11  disposition    52179 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 4.8+ MB

# %%
# Mengubah tipe data ke numeric 
homicide['victim_age'] = pd.to_numeric(homicide['victim_age'], errors='coerce')
homicide.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4  Alb-000005       20100102         MULA       VIVIAN       White
#
#    victim_age victim_sex         city state        lat         lon  \
# 0        78.0       Male  Albuquerque    NM  35.095788 -106.538555
# 1        17.0       Male  Albuquerque    NM  35.056810 -106.715321
# 2        15.0     Female  Albuquerque    NM  35.086092 -106.695568
# 3        32.0       Male  Albuquerque    NM  35.078493 -106.556094
# 4        72.0     Female  Albuquerque    NM  35.130357 -106.580986
#
#              disposition
# 0  Closed without arrest
# 1       Closed by arrest
# 2  Closed without arrest
# 3       Closed by arrest
# 4  Closed without arrest

# %%
# mengubah tipe data ke numeric
homicide["lat"] = pd.to_numeric(homicide["lat"], errors='coerce')
homicide.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4  Alb-000005       20100102         MULA       VIVIAN       White
#
#    victim_age victim_sex         city state        lat         lon  \
# 0        78.0       Male  Albuquerque    NM  35.095788 -106.538555
# 1        17.0       Male  Albuquerque    NM  35.056810 -106.715321
# 2        15.0     Female  Albuquerque    NM  35.086092 -106.695568
# 3        32.0       Male  Albuquerque    NM  35.078493 -106.556094
# 4        72.0     Female  Albuquerque    NM  35.130357 -106.580986
#
#              disposition
# 0  Closed without arrest
# 1       Closed by arrest
# 2  Closed without arrest
# 3       Closed by arrest
# 4  Closed without arrest

# %%
# mengubah tipe data ke numeric
homicide["lon"] = pd.to_numeric(homicide["lon"], errors='coerce')
homicide.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4  Alb-000005       20100102         MULA       VIVIAN       White
#
#    victim_age victim_sex         city state        lat         lon  \
# 0        78.0       Male  Albuquerque    NM  35.095788 -106.538555
# 1        17.0       Male  Albuquerque    NM  35.056810 -106.715321
# 2        15.0     Female  Albuquerque    NM  35.086092 -106.695568
# 3        32.0       Male  Albuquerque    NM  35.078493 -106.556094
# 4        72.0     Female  Albuquerque    NM  35.130357 -106.580986
#
#              disposition
# 0  Closed without arrest
# 1       Closed by arrest
# 2  Closed without arrest
# 3       Closed by arrest
# 4  Closed without arrest

# %% [markdown]
# ### NUMBER 2

# %% [markdown]
# ### a. Data Visualization

# %%
# Plot untuk menapilkan apakah ada missing data

sns.heatmap(homicide.isnull(), cbar=False, cmap="YlGnBu")
sns.set(rc = {'figure.figsize':(20,10)})
plt.title('Missing Data')
plt.show()

# %%
# Boxplot 
colors = sns.color_palette('pastel')[0:5]

plt.figure(figsize=(15, 5))
sns.countplot(x='city', data=homicide, palette=colors)

# Mengatur label nama negara agar tidak tumpang tindih
plt.xticks(rotation=90, ha='right')

# Menampilkan plot
plt.tight_layout()
plt.title('Kasus Pembunuhan di Amerika')
plt.show()

# %% [markdown]
# #### Penjelasan :
# Dari hasil visualisasi data 'City' menggunakan BoxPlot dapat disimpulkan bahwa kasus pembunuhan kriminal di 50 kota terbesar di Amerika kasus terbanyak pertama ada di Chicago, kedua ada di 'Philadelphia', dan ketiga ada di 'Houston'.

# %%
import matplotlib.pyplot as plt

colors = ['#FFB3B3', '#FFEB99', '#A8E6A1'] 
total_age = homicide['victim_age'].sum()
gender_percentage = (homicide.groupby('victim_sex')['victim_age'].sum() / total_age) * 100

plt.pie(gender_percentage, 
        labels=gender_percentage.index, 
        autopct='%1.1f%%', 
        colors=colors, 
        textprops={'fontsize': 14}) 

plt.title('Persentase Korban Pembunuhan berdasarkan Jenis Kelamin', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# #### Penjelasan:
# - Male = 81.2%
# - Female = 15.5%
# - Unknown (jenis kelamin tidak diketahui) = 3.3%
#
# Berdasarkan dari hasil Visualisasi data menggunakan Pie Chart diatas, dapat disimpulkan bahwa Pria memiliki nilai presentase paling tinggi yaitu 81.2% yang berarti kasus pembunuhan kriminal di 50 kota terbesar di Amerika korban di dominasi oleh 'Pria'

# %%
# Data Visualization : 

colors = sns.color_palette('pastel')[3:4]

# Filter data untuk kota-kota tertentu: Chicago, Philadelphia, dan Houston
selected_cities = ['Chicago', 'Philadelphia', 'Houston']
filtered_homicide = homicide[homicide['city'].isin(selected_cities)]

plt.figure(figsize=(10, 6))
sns.countplot(data=filtered_homicide,
              y="disposition", 
              hue="city",
              palette="pastel")

plt.title('Penyelesaian Kasus Pembunuhan di Chicago, Philadelphia, Houston')
plt.xlabel('Count')
plt.ylabel('Disposition')
plt.legend(title='City', 
           loc='upper right')


plt.show()

# %% [markdown]
# #### Penjelasan:
# Berdasarkan hasil Visualisasi data diatas, Grafik diatas bertujuan untuk membandingkan jumlah kasus di tiga kota, yaitu Chicago, Philadelphia, dan Houston. Selain itu, dibagi lagi menjadi tiga kategori untuk status kasus yang terdiri dari:
# - Ditutup dengan penangkapan.
# - Ditutup tanpa penangkapan.
# - Terbuka/tidak ada penangkapan.
#
# Hasil:
# - Philadelphia memiliki jumlah kasus tertinggi yang ditutup dengan penangkapan.
# - Chicago memiliki jumlah kasus tertinggi yang ditutup tanpa penangkapan.
# - Chicago memiliki jumlah kasus terbuka/tidak ada penangkapan tertinggi.

# %%
# Data Visualization : KDE Plot
colors = sns.color_palette('pastel')[3:4]
ax = sns.histplot(data=homicide, x="victim_race", 
             color=colors[0], 
             kde=True, 
             bins=10, 
             binwidth=3)

ax.set_title('KDE Plot : Etnis / Ras Korban')
plt.show()

# %% [markdown]
# #### Penjelasan:
# Berdasarkan hasil Visualisasi data diatas, Grafik menunjukkan distribusi ras korban dalam dataset yang digunakan.
# Hasil:
# - Data korban tertinggi pertama = "black".
# - Data korban tertinggi kedua = "hispanic".
# - Data korban tertinggi ketiga = "white".

# %% [markdown]
# ## b. Exploratory Data Analysis

# %%
homicide.describe()
# Out:
#        reported_date    victim_age           lat           lon
# count   5.217900e+04  49180.000000  52119.000000  52119.000000
# mean    2.013090e+07     31.801220     37.026786    -91.471094
# std     1.123420e+06     14.418692      4.348647     13.746378
# min     2.007010e+07      0.000000     25.725214   -122.507779
# 25%     2.010032e+07     22.000000     33.765203    -95.997198
# 50%     2.012122e+07     28.000000     38.524973    -87.710286
# 75%     2.015091e+07     40.000000     40.027627    -81.755909
# max     2.015111e+08    102.000000     45.051190    -71.011519

# %% [markdown]
# ### Use IQR (Interquartile Range)to find outlier in dataset and describe the result.

# %%
vicage = homicide[['victim_age']]
vicage.shape
# Out:
# (52179, 1)

# %%
# Menggunakan visualisasi 'Boxplot' untuk melihat apakah terdapat outlier atau tidak.
plt.figure(figsize=(10,10))
homicide.boxplot(column=['victim_age'])
plt.title('Boxplot : Outlier pada Victim_age')
plt.show()

# %%
# Mencari quartile

Q1 = homicide['victim_age'].quantile(0.25)
Q3 = homicide['victim_age'].quantile(0.75)

Q1, Q3
# Out:
# (22.0, 40.0)

# %%
# Mencari IQR 
IQR = Q3 - Q1
IQR
# Out:
# 18.0

# %%
# lower_limit dan upper_limit

lowwer_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

lowwer_limit,upper_limit
# Out:
# (-5.0, 67.0)

# %%
# Menampilkan data Outlier
homicide[(homicide['victim_age'] < lowwer_limit) | (homicide['victim_age'] > upper_limit) ]
# Out:
#               uid  reported_date victim_last victim_first victim_race  \
# 0      Alb-000001       20100504      GARCIA         JUAN    Hispanic
# 4      Alb-000005       20100102        MULA       VIVIAN       White
# 5      Alb-000006       20100126        BOOK    GERALDINE       White
# 24     Alb-000025       20100602     WRONSKI        VIOLA       White
# 37     Alb-000038       20100916    PHILLIPS      MADELYN       Other
# ...           ...            ...         ...          ...         ...
# 51873  Was-001071       20070125    MATTHEWS         LOIS       Black
# 51900  Was-001098       20070329       BROWN       HOWARD       Black
# 51939  Was-001137       20070615      LITTLE      WILLIAM       Black
# 51978  Was-001176       20070825        SHAW         JOHN       Black
# 52054  Was-001253       20160810     SPENCER     HARRISON       White
#
#        victim_age victim_sex         city state        lat         lon  \
# ...

# %%
# menampilkan tanpa outlier
homicide[(homicide['victim_age'] > lowwer_limit) & (homicide['victim_age'] < upper_limit) ]
# Out:
#               uid  reported_date  victim_last victim_first victim_race  \
# 1      Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2      Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3      Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 6      Alb-000007       20100127    MALDONADO        DAVID    Hispanic
# 7      Alb-000008       20100127    MALDONADO       CONNIE    Hispanic
# ...           ...            ...          ...          ...         ...
# 52174  Was-001380       20160908     WILLIAMS         EVAN       Black
# 52175  Was-001381       20160913        SMITH         DEON       Black
# 52176  Was-001382       20161114   WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130       BARNES       MARCUS       Black
# 52178  Was-001384       20160901      JACKSON        KEVIN       Black
#
#        victim_age victim_sex         city state        lat         lon  \
# ...

# %%
# Remove Outlier
# Menyimpan data no outlier ke var baru
no_outlier = homicide[(homicide['victim_age'] > lowwer_limit) & (homicide['victim_age'] < upper_limit)]
no_outlier
# Out:
#               uid  reported_date  victim_last victim_first victim_race  \
# 1      Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2      Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3      Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 6      Alb-000007       20100127    MALDONADO        DAVID    Hispanic
# 7      Alb-000008       20100127    MALDONADO       CONNIE    Hispanic
# ...           ...            ...          ...          ...         ...
# 52174  Was-001380       20160908     WILLIAMS         EVAN       Black
# 52175  Was-001381       20160913        SMITH         DEON       Black
# 52176  Was-001382       20161114   WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130       BARNES       MARCUS       Black
# 52178  Was-001384       20160901      JACKSON        KEVIN       Black
#
#        victim_age victim_sex         city state        lat         lon  \
# ...

# %%
# Outlier setelah di hapus
Q1 = no_outlier['victim_age'].quantile(0.25)
Q3 = no_outlier['victim_age'].quantile(0.75)

Q1, Q3
# Out:
# (22.0, 38.0)

# %%
# Mencari IQR 
IQR = Q3 - Q1
IQR
# Out:
# 16.0

# %%
# lower_limit dan upper_limit

lowwer_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR

lowwer_limit,upper_limit
# Out:
# (-2.0, 62.0)

# %%
plt.figure(figsize=(10,10))
no_outlier.boxplot(column=['victim_age'])
plt.title('Boxplot : Outlier yang sudah dihapus')
plt.show()

# %%
homicide.shape[0] - no_outlier.shape[0]
# Out:
# 4201

# %% [markdown]
# ##### Penjelasan - outlier pada table 'victim_age':
#
# Nilai outlier sebelum dihapus : (-5.0, 67.0)
# Nilai outlier sesduah dihapus : (-2.0, 62.0)

# %% [markdown]
# ### c. Data Preprocessing and Preparation

# %% [markdown]
# #### a. use binning or encoding

# %%
# binning
# Membuat bins untuk mengelompokkan data umur ke dalam interval.
bin = np.linspace(min(homicide['victim_age']), max(homicide['victim_age']), 6)
bin
# Out:
# array([  0. ,  20.4,  40.8,  61.2,  81.6, 102. ])

# %%
# Membuat kategori Umur berdasarkan column 'victim_age'
homicide['age_category'] = np.where(
    (homicide['victim_age'] >= 16) & (homicide['victim_age'] <= 23), 'Remaja Dewasa',
    np.where((homicide['victim_age'] >= 24) & (homicide['victim_age'] <= 35), 'Dewasa Awal',
             np.where((homicide['victim_age'] >= 36) & (homicide['victim_age'] <= 59), 'Dewasa Menengah',
                      np.where(homicide['victim_age'] > 60, 'Lansia', 'Anak-Anak')))
)

homicide

# Kategori: 
# Anak-anak : 0-15 Tahun
# Remaja Dewasa : 16 - 23 Tahun
# Dewasa Awal : 24 - 35 Tahun
# Dewasa Menengah : 36 - 59 Tahun
# Lansia : 60 > Tahun
# Out:
#               uid  reported_date  victim_last victim_first victim_race  \
# 0      Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1      Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2      Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3      Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4      Alb-000005       20100102         MULA       VIVIAN       White
# ...           ...            ...          ...          ...         ...
# 52174  Was-001380       20160908     WILLIAMS         EVAN       Black
# 52175  Was-001381       20160913        SMITH         DEON       Black
# 52176  Was-001382       20161114   WASHINGTON       WILLIE       Black
# 52177  Was-001383       20161130       BARNES       MARCUS       Black
# 52178  Was-001384       20160901      JACKSON        KEVIN       Black
#
#        victim_age victim_sex         city state        lat         lon  \
# ...

# %%
# Data Visualization : Pie Chart

age_category_counts = homicide['age_category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(age_category_counts, labels=age_category_counts.index, autopct='%1.1f%%')
plt.title('Distribusi Korban Pembunuhan Berdasarkan Kategori Usia')
plt.show()

# %% [markdown]
# #### Penjelasan:
# Hasil:
# - Dewasa Awal : 33.61%.
# - Remaja Dewas : 26.1%.
# - Dewasa Menengah : 25.76%.
# - Anak-Anak : 10.5%
# - Lansia : 4.1%.
#
# Kesimpulan: Seperti pada Pie Chart diatas menunjukan bahwa korban pembunuhan berdasarkan kategori usia didominasi oleh katoegori Dewasa Awal (24 - 35 tahun)

# %% [markdown]
# #### b. Normalize the Data

# %%
min_max = homicide[['victim_age', 'lat', 'lon']]

# %%
# untuk normalisasi menggunakan Min Max pada kolom 'victim_age','lat', dan 'lon'

for column in min_max.columns:
    min_max[column] = (min_max[column] - min_max[column].min()) / (min_max[column].max() - min_max[column].min())
min_max.head()
# Out:
# C:\Users\Dedy\AppData\Local\Temp\ipykernel_26968\2983160619.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_max[column] = (min_max[column] - min_max[column].min()) / (min_max[column].max() - min_max[column].min())
#    victim_age       lat       lon
# 0    0.764706  0.484869  0.310105
# 1    0.166667  0.482853  0.306672
# 2    0.147059  0.484368  0.307056
# 3    0.313725  0.483974  0.309764
# 4    0.705882  0.486658  0.309281

# %%
#menampilkan plot normalisasi
min_max.hist(figsize=(10, 10))
plt.title('Histogram Normalisasi Data')
plt.show()

# %%
import datetime
import uuid

studentName = "Rhauma Syira Anggina"
studentNIM = "00000079236"
studentClass = "IS388-C"

# %%
myDate = datetime.datetime.now()
myDevice = str(uuid.uuid1())

print("Name: \t\t{}".format(studentName))
print("NIM: \t\t{}".format(studentNIM))
print("NIM: \t\t{}".format(studentClass))
print("Start: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Rhauma Syira Anggina
# NIM: 		00000079236
# NIM: 		IS388-C
# Start: 		2023-10-20 19:06:55.157942
# Device ID: 	294db31f-6f41-11ee-b9bd-9843fa3c851a
